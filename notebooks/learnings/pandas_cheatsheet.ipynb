# %%
# 1 - Importing Pandas
import pandas as pd

# 2 - Reading Data
df = pd.read_csv("file.csv")
# You can also read data from other sources like Excel, SQL, etc.

# 3 - DataFrame Operations
# Get the shape of the dataframe
df.shape

# Get the first n rows of the dataframe
df.head(n)

# Get the last n rows of the dataframe
df.tail(n)

# Get a summary of the dataframe
df.info()

# Get the column names of the dataframe
df.columns

# Get the statistics of the dataframe
df.describe()

# Get the value counts of a column
df['column_name'].value_counts()

# 4 - Selecting Data
# Select a single column
df['column_name']
df.column_name

# Select multiple columns
df[['column1', 'column2']]

# Select rows based on conditions
df[df['column_name'] > value]
df[df['column_name'].isin(values)]

# Select rows based on multiple conditions
df[(df['column1'] > value1) & (df['column2'] > 10)]
df[(df['column1'] > value1) | (df['column2'] < value2)]

# Select rows with query methods
df.query('column1 == @value1 and column2 > 10')

# Select rows by index
df.loc[index]
df.loc[start:end]
df.loc[index, ['column1', 'column2']]

# Select rows by position
df.iloc[position]
df.iloc[start:end]
df.iloc[position, [0, 1]]

# 5 - Data Cleaning
# Remove missing values, axis= 0 for row OR 1 for column
df.dropna()
df.dropna(subset=["column1"], axis=0)

# Replace a value by a new one
df["column1"].replace("?", np.nan)

# Fill missing values with a value
df.fillna(value)

# Remove duplicates
df.drop_duplicates()

# 6 - Grouping and Aggregating
# Group by a column and aggregate using mean
df.groupby('column_name').mean()

# Group by multiple columns and aggregate using mean
df.groupby(['column1', 'column2']).mean()

# Aggregate using multiple functions
df.groupby('column_name').agg(['mean', 'median'])

# 7 - Merging and Joining
# Merge two dataframes on a common column
df1.merge(df2, on='column_name')

# Join two dataframes on a common index
df1.join(df2)

# 8 - Sorting and Reordering
# Sort by a column in ascending order
df.sort_values('column_name')

# Sort by a column in descending order
df.sort_values('column_name', ascending=False)

# Reorder the columns in a dataframe
df[['column3', 'column1', 'column2']]

# 9 - Pivot Tables
# Create a pivot table
df.pivot_table(values='column_name', index='index_column', columns='column_to_group_by')

# 10 - Adding, Removing & Updating Columns
# Add a new column
df['new_column'] = values

# Remove a column
df.drop('column_name', axis=1)

# Update selected rows
my_condition = (df['column1'] > value1) & (df['column2'] < value2)
df.loc[my_condition, 'column_name'] = new_value

# 11 - Saving Data
# Save data to a CSV file
df.to_csv('file.csv', index=False)

# Save data to an Excel file
df.to_excel('file.xlsx', index=False)

# 12 - Plotting Data
# Plot a line chart
df.plot(kind='line')

# Plot a bar chart
df.plot(kind='bar')

# Plot a histogram
df.plot(kind='hist')

# Plot a scatter plot
df.plot(kind='scatter', x='column_name', y='column_name')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a9aff3de219f> in <module>
#       3
#       4 # 2 - Reading Data
# ----> 5 df = pd.read_csv("file.csv")
#       6 # You can also read data from other sources like Excel, SQL, etc.
#       7
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
