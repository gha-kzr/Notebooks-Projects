# %%
import json
import seaborn as sns
import pandas as pd

sns.set(rc={'figure.figsize':(30,8.27)})

# %%
filepath = "/content/drive/MyDrive/Colab Notebooks/Projects/job_list_with_skills.csv"
df = pd.read_csv(filepath, sep =',')

# %%
filepath = "/content/drive/MyDrive/Colab Notebooks/Projects/job_list_with_skills.json"
df = pd.read_json(filepath)

# %%
#df['skills'] = df['skills'].apply(lambda x: json.loads(x))

# %%
df.head()
# Out:
#            id                                      title  \
# 0  3427436026                               Data Analyst
# 1  3479541484                         Data Scientist H/F
# 2  3477087459                Creative Data Analyst - CDD
# 3  3479121451  Chef de projet AMOA Data management (F/H)
# 4  3473259005            Consultant(e) Data Strategy H/F
#
#                 company                                                url  \
# 0       Foxintelligence  https://fr.linkedin.com/jobs/view/data-analyst...
# 1                AGYLIS  https://fr.linkedin.com/jobs/view/data-scienti...
# 2                CHANEL  https://fr.linkedin.com/jobs/view/creative-dat...
# 3     Médecins du Monde  https://fr.linkedin.com/jobs/view/chef-de-proj...
# 4  DataValue Consulting  https://fr.linkedin.com/jobs/view/consultant-e...
#
#                                       location       date  \
# 0                 Paris, Île-de-France, France 2023-02-11
# 1  Boulogne-Billancourt, Île-de-France, France 2023-02-11
# 2     Neuilly-sur-Seine, Île-de-France, France 2023-02-10
# 3             St.-Denis, Île-de-France, France 2023-02-11
# 4             Montrouge, Île-de-France, France 2023-02-11
#
#                                               skills       new_title
# 0  [process, code, cloud, app, google, play, mark...    Data Analyst
# 1   [google, python, test, data, client, cloud, sql]  Data Scientist
# 2  [bi, process, management, creative, production...    Data Analyst
# 3  [monitoring, management, go, data, sites, prod...     Data Others
# 4  [certification, business, analytics, managemen...     Data Others

# %%
df_title = df[['new_title', 'id']].groupby(['new_title']).count()
df_title = df_title.sort_values(by=['id'], ascending=False)
df_title = df_title.reset_index()
df_title = df_title.rename(columns={'id':"Nombre d'offre", 'new_title': 'Offre'})

# %%
ax = sns.barplot(data=df_title, x='Offre', y="Nombre d'offre",errwidth=0)

# %%
df[df['new_title'] == 'Others']['title'].head()
# Out:
# 7                          Support - Analyst IT Run H/F
# 10                               Business Analyst (H/F)
# 18                                     Business Analyst
# 20                               Développeur PYTHON H/F
# 26    Chargé(e) d'Etudes Quantitatives, Département ...
# Name: title, dtype: object

# %%
df[df['new_title'] == 'Data Others']['title'].head()
# Out:
# 3             Chef de projet AMOA Data management (F/H)
# 4                       Consultant(e) Data Strategy H/F
# 5               Big Data en Alternance Octobre 2022 H/F
# 12            Our Data Science internship opportunities
# 14    Directeur Data Management - Transport & Mobili...
# Name: title, dtype: object

# %%
df2 = df.explode('skills')
df2.head()
# Out:
#            id         title          company  \
# 0  3427436026  Data Analyst  Foxintelligence
# 0  3427436026  Data Analyst  Foxintelligence
# 0  3427436026  Data Analyst  Foxintelligence
# 0  3427436026  Data Analyst  Foxintelligence
# 0  3427436026  Data Analyst  Foxintelligence
#
#                                                  url  \
# 0  https://fr.linkedin.com/jobs/view/data-analyst...
# 0  https://fr.linkedin.com/jobs/view/data-analyst...
# 0  https://fr.linkedin.com/jobs/view/data-analyst...
# 0  https://fr.linkedin.com/jobs/view/data-analyst...
# 0  https://fr.linkedin.com/jobs/view/data-analyst...
#
#                        location       date   skills     new_title
# 0  Paris, Île-de-France, France 2023-02-11  process  Data Analyst
# 0  Paris, Île-de-France, France 2023-02-11     code  Data Analyst
# 0  Paris, Île-de-France, France 2023-02-11    cloud  Data Analyst
# 0  Paris, Île-de-France, France 2023-02-11      app  Data Analyst
# 0  Paris, Île-de-France, France 2023-02-11   google  Data Analyst

# %%
df_skills = df2[['skills', 'id']].groupby(['skills']).count()
df_skills = df_skills.sort_values(by=['id'], ascending=False)
df_skills = df_skills.reset_index()
df_skills = df_skills.rename(columns={'id':"Nombre d'offre", 'new_title': 'Offre'})

# %%
df_skills.head()
# Out:
#         skills  Nombre d'offre
# 0         data             366
# 1   management             188
# 2     business             175
# 3       client             130
# 4  performance             125

# %%
df_skills.count()
# Out:
# skills            371
# Nombre d'offre    371
# dtype: int64

# %%
# On ne garde que les compétences qui apparaissent au moinx 5 fois pour réduire le dataframe
df_skills_reduced = df_skills[df_skills["Nombre d'offre"] > 1]
df_skills_reduced.count()
# Out:
# skills            296
# Nombre d'offre    296
# dtype: int64

# %%
skill_list_str = ""
for value in df_skills_reduced['skills']:
    skill_list_str += "'" + value + "',"

print(skill_list_str)
# Out:
# 'data','management','business','client','performance','c','process','tech','marketing','manager','cloud','collaboration','production','knowledge','design','development','build','sql','analytics','python','web','software','tools','help','audit','code','documentation','devops','java','status','bi','time','flexible','growth','microsoft','sites','monitoring','privacy','font','aws','systems','stack','security','vue','docker','certification','validation','test','linux','research','guidelines','dynamic','framework','mobile','language','git','google','kubernetes','api','progress','player','e-commerce','angular','system','configuration','saas','presentations','creative','education','spark','react','head','php','community','exploitation','fast','models','metrics','standard','functional','programming','content','alignment','efficiency','utilities','js','free','go','testing','apis','network','form','collection','resources','server','flux','automation','javascript','ansible','interview','rest','scale','enterprise','views','windows','animation','guide','elasticsearch','forms','symfony','types','play','email','ux','developer','optimization','search','requests','postgresql','activity','website','principles','deploy','storage','scalable','date','material','spring','end-to-end','redis','jobs','view','scripting','database','mysql','collections','dashboards','flow','node','modules','distributed','ui','universal','apps','unix','packages','statistics','ide','hadoop','serverless','select','videos','youtube','example','deployment','erp','agent','components','shell','templates','tdd','scala','json','android','frontend','bash','simple','ios','vpn','offline','benchmark','resource','c++','nlp','bdd','list','calendar','careers','django','courses','apache','typescript','html5','productivity','microservices','front-end','game','message','iot','mail','minimal','messaging','nodejs','coverage','mongodb','graphql','redux','accessibility','high-performance','yaml','visualization','container','html','websocket','consensus','reactjs','robotics','mvp','perfect','constraints','payments','promise','guides','databases','scheduling','css','orchestration','dashboard','prototypes','prometheus','bigquery','swift','app','links','extension','tour','file','volume','examples','less','input','laravel','adobe','middleware','image','easy','streaming','qa','serialization','facebook','component','video','reactive','files','containers','inheritance','intranet','ruby','golang','css3','ml','button','networking','best-practices','card','oop','desktop','open-source','tap','notifications','pandas','architectural','apple','blog','book','yarn','responsive','community-driven','binaries','rust','snippets','coding','watch','authentication','athena','cluster','sdk','service-oriented','slides','3d','data-mining','correct','matlab','mit','libraries','decentralized','numpy','observer','phone','photos','cross-platform','powershell','expectation','proxy','hosting','real-time',

# %%
black_list = ['c', 'data','plus','clients','nous','missions','solutions','management','place','business','work','france','services','international','service','support','client','performance','expertise','experience','techniques','communication','team','process','technologies','paris','mission','skills','leader','transformation','description','tech','technique','information','marketing','charge','part','manager','english','initiatives','global','forte','collaboration','years','culture','digital','teams','impact','finance','role','production','site','actions','knowledge','esprit','plan','world','strong','ensemble','applications','company','what','inclusion','people','type','sans','working','leadership','great','design','commerce','respect','opportunities','force','architecture','direction','build','technology','product','development','intelligence','durable','lead','solution','ability','orientation','across','recrutement','analytics','innovation','within','develop','application','cabinet','opportunity','based','vision','environment','best','including','programme','employees','unique','oral','engagement','office','minimum','excellent','master','organisation','consultants','project','ensure','software','proposition','plans','engineering','possible','internal','tools','diverse','create','strategy','continue','french','help','well','looking','projects','responsibilities','risk','most','written','challenges','europe','cycle','sales','improve','future','join','participation','customers']
black_list += ['audit', 'code', 'documentation', 'status', 'time', 'flexible', 'growth', 'sites', 'privacy', 'font', 'stack', 'vue']
white_listed = df_skills_reduced['skills'].map(lambda x : x not in black_list)
white_df = df_skills_reduced[white_listed]

# %%
#sns.barplot(data=white_df, x='skills', y="Nombre d'offre").set_yticks(range(int(min(white_df["Nombre d'offre"])), int(max(white_df["Nombre d'offre"])) + 1))
sns.barplot(data=white_df.head(15), x='skills', y="Nombre d'offre")

# %%
df_skills2 = df2[['new_title', 'skills', 'id']].groupby(['new_title', 'skills']).count()
df_skills2 = df_skills2.reset_index()
df_skills2 = df_skills2.sort_values(by=['id'], ascending=False)
df_skills2 = df_skills2.rename(columns={'id':"Nombre d'offre", 'new_title': 'Offre'})
#df_skills2 = df_skills2[df_skills2["Nombre d'offre"] > 2]
df_skills2 = df_skills2[df_skills2['skills'].map(lambda x : x not in black_list)]

# %%
df_skills2[df_skills2['Offre'] == 'Data Analyst'].head()
# Out:
#             Offre  skills  Nombre d'offre
# 522  Data Analyst  python               6
# 527  Data Analyst     sql               6
# 478  Data Analyst      bi               4
# 477  Data Analyst    apps               3
# 502  Data Analyst  google               3

# %%
df_skills2[df_skills2['Offre'] == 'Data Scientist'].head()
# Out:
#               Offre  skills  Nombre d'offre
# 794  Data Scientist  python               5
# 796  Data Scientist     sql               4
# 759  Data Scientist   audit               2
# 788  Data Scientist  pandas               2
# 775  Data Scientist     git               2

# %%
df_skills2[df_skills2['Offre'] == 'Data Engineer'].head()
# Out:
#              Offre  skills  Nombre d'offre
# 747  Data Engineer   spark               8
# 744  Data Engineer  python               7
# 748  Data Engineer     sql               5
# 726  Data Engineer  hadoop               5
# 712  Data Engineer   cloud               5

# %%
df_skills2[df_skills2['Offre'] == 'Autres'].head()
# Out:
#       Offre  skills  Nombre d'offre
# 52   Autres   cloud              67
# 330  Autres     web              52
# 288  Autres     sql              36
# 308  Autres    time              35
# 293  Autres  status              35

# %%
df_skills2[(df_skills2['Offre'] == 'Data Autres') & (df_skills2['skills'] == 'dataiku')]
# Out:
# Empty DataFrame
# Columns: [Offre, skills, Nombre d'offre]
# Index: []

# %%
def get_jobs_from_title(df, title):
  return df[df['new_title'] == title]

def get_jobs_from_skills(df, skills):
  return df[df['skills'] == skills]

get_jobs_from_title(df, 'Data Engineer')
# Out:
#              id                                   title             company  \
# 22   3478387224                  Lead data engineer H/F      Robert Walters
# 25   3479560907                       Data Engineer H/F  B-Hive Engineering
# 96   3450777859                     Data engineer - AWS             Harnham
# 98   3447260210  Data Engineer - Financial Services H/F                 CGI
# 111  3383208891        SOFTWARE ENGINEER BIG DATA-(H/F)    Societe Generale
# 148  3450777859                     Data engineer - AWS             Harnham
# 152  3450777859                     Data engineer - AWS             Harnham
# 155  3447260210  Data Engineer - Financial Services H/F                 CGI
# 168  3383208891        SOFTWARE ENGINEER BIG DATA-(H/F)    Societe Generale
# 228  3460112961                      Lead data engineer             Harnham
# 271  3352105810                Data Engineering Manager             Harnham
#
#                                                    url  \
# 22   https://fr.linkedin.com/jobs/view/lead-data-en...
# 25   https://fr.linkedin.com/jobs/view/data-enginee...
# 96   https://fr.linkedin.com/jobs/view/data-enginee...
# 98   https://fr.linkedin.com/jobs/view/data-enginee...
# 111  https://fr.linkedin.com/jobs/view/software-eng...
# 148  https://fr.linkedin.com/jobs/view/data-enginee...
# 152  https://fr.linkedin.com/jobs/view/data-enginee...
# 155  https://fr.linkedin.com/jobs/view/data-enginee...
# 168  https://fr.linkedin.com/jobs/view/software-eng...
# 228  https://fr.linkedin.com/jobs/view/lead-data-en...
# 271  https://fr.linkedin.com/jobs/view/data-enginee...
#
#                                       location       date  \
# 22                Paris, Île-de-France, France 2023-02-10
# 25             Nanterre, Île-de-France, France 2023-02-11
# 96                Paris, Île-de-France, France 2023-02-11
# 98                Paris, Île-de-France, France 2023-02-11
# 111  Fontenay-sous-Bois, Île-de-France, France 2023-02-11
# 148               Paris, Île-de-France, France 2023-02-11
# 152               Paris, Île-de-France, France 2023-02-11
# 155               Paris, Île-de-France, France 2023-02-11
# 168  Fontenay-sous-Bois, Île-de-France, France 2023-02-11
# 228               Paris, Île-de-France, France 2023-02-11
# 271               Paris, Île-de-France, France 2023-02-11
#
#                                                 skills      new_title
# 22   [flux, analytics, management, collaboration, d...  Data Engineer
# 25   [ansible, git, influxdb, prometheus, stack, aw...  Data Engineer
# 96   [apis, build, python, aws, process, devops, da...  Data Engineer
# 98   [prototypes, yarn, vue, standard, management, ...  Data Engineer
# 111  [code, data, scala, hadoop, tech, production, ...  Data Engineer
# 148  [apis, build, python, aws, process, devops, da...  Data Engineer
# 152  [apis, build, python, aws, process, devops, da...  Data Engineer
# 155  [prototypes, yarn, vue, standard, management, ...  Data Engineer
# 168  [code, data, scala, hadoop, tech, production, ...  Data Engineer
# 228  [apis, flux, streaming, marketing, python, pro...  Data Engineer
# 271  [google, numpy, business, python, stack, aws, ...  Data Engineer

# %%
get_jobs_from_skills(df2, 'certification')
# Out:
#              id                                              title  \
# 4    3473259005                    Consultant(e) Data Strategy H/F
# 11   3478541997                            Data Scientist Confirmé
# 63   3467300908                    Analyste Risque de Marché (F/H)
# 82   3285625294  Clinical Research Associate - all level of exp...
# 99   3444086627                    Stagiaire Data Protection (H/F)
# 113  3444097252       Stagiaire data security, data protection H/F
# 115  3467033977  Head of Cloud Datalake platform for Corporate ...
# 132  3285625294  Clinical Research Associate - all level of exp...
# 156  3444086627                    Stagiaire Data Protection (H/F)
# 170  3444097252       Stagiaire data security, data protection H/F
# 174  3467033977  Head of Cloud Datalake platform for Corporate ...
# 210  3447275237            Analyste métriques risque finance-(H/F)
# 244  3477085847              Senior Consultant Project Development
# 254  3444098451  Customer Data Platform (CDP) Specialist / Cust...
# 272  3477089390  Manager Carbon Project Development, Community-...
# 274  3271366588  Associate Manager Start-Up France / Sponsor de...
# 281  3444278144  Stage - Ingénieur d'extension d'une solution d...
# 292  3444094583                                Architecte SI (H/F)
# 307  3444093129       Manager/ Senior Manager Data & Privacy (H/F)
# 312  3443786186          Enterprise Information Security Architect
# 315  3444273917  Stage - Ingénieur d'extension d'une solution d...
# 316  3444280015  Stage - Ingénieur d'extension d'une solution d...
# 323  3444280072  Stage - Ingénieur d'extension d'une solution d...
# 325  3444280072  Stage - Ingénieur d'extension d'une solution d...
# 329  3479593939                             Ingénieur Réseau (H/F)
# 347  3444086710  Confidential Data Protection Risk Management -...
# 351  3444088973       Consultant expérimenté Data Protection (H/F)
# 357  3271363897          Senior Clinical Data Manager - Late Phase
# 360  3477091369           DEVELOPPEUR FULLSTACK JAVA/ANGULAR (H/F)
# 361  3477090379           DEVELOPPEUR FULLSTACK JAVA/ANGULAR (H/F)
# 363  3364557519   International EMEA Bid Manager - French Speaking
# 371  3479595545                                   Développeur Java
#
#                         company  \
# 4          DataValue Consulting
# 11               SYNERGY FRANCE
# 63   Jobs via eFinancialCareers
# 82                      Labcorp
# 99                     Deloitte
# 113                    Deloitte
# 115  Jobs via eFinancialCareers
# 132                     Labcorp
# 156                    Deloitte
# 170                    Deloitte
# 174  Jobs via eFinancialCareers
# 210            Societe Generale
# 244                        Atos
# 254                    Deloitte
# 272                        Atos
# 274                     Labcorp
# 281                        Atos
# 292                    Deloitte
# 307                    Deloitte
# 312                    Givaudan
# 315                        Atos
# 316                        Atos
# 323                        Atos
# 325                        Atos
# 329           Société Free-Work
# 347                    Deloitte
# 351                    Deloitte
# 357                     Labcorp
# 360                        Atos
# 361                        Atos
# 363     SHI International Corp.
# 371           Société Free-Work
#
#                                                    url  \
# 4    https://fr.linkedin.com/jobs/view/consultant-e...
# 11   https://fr.linkedin.com/jobs/view/data-scienti...
# 63   https://fr.linkedin.com/jobs/view/analyste-ris...
# 82   https://fr.linkedin.com/jobs/view/clinical-res...
# 99   https://fr.linkedin.com/jobs/view/stagiaire-da...
# 113  https://fr.linkedin.com/jobs/view/stagiaire-da...
# 115  https://fr.linkedin.com/jobs/view/head-of-clou...
# 132  https://fr.linkedin.com/jobs/view/clinical-res...
# 156  https://fr.linkedin.com/jobs/view/stagiaire-da...
# 170  https://fr.linkedin.com/jobs/view/stagiaire-da...
# 174  https://fr.linkedin.com/jobs/view/head-of-clou...
# 210  https://fr.linkedin.com/jobs/view/analyste-m%C...
# 244  https://fr.linkedin.com/jobs/view/senior-consu...
# 254  https://fr.linkedin.com/jobs/view/customer-dat...
# 272  https://fr.linkedin.com/jobs/view/manager-carb...
# 274  https://fr.linkedin.com/jobs/view/associate-ma...
# 281  https://fr.linkedin.com/jobs/view/stage-ing%C3...
# 292  https://fr.linkedin.com/jobs/view/architecte-s...
# 307  https://fr.linkedin.com/jobs/view/manager-seni...
# 312  https://fr.linkedin.com/jobs/view/enterprise-i...
# 315  https://fr.linkedin.com/jobs/view/stage-ing%C3...
# 316  https://fr.linkedin.com/jobs/view/stage-ing%C3...
# 323  https://fr.linkedin.com/jobs/view/stage-ing%C3...
# 325  https://fr.linkedin.com/jobs/view/stage-ing%C3...
# 329  https://fr.linkedin.com/jobs/view/ing%C3%A9nie...
# 347  https://fr.linkedin.com/jobs/view/confidential...
# 351  https://fr.linkedin.com/jobs/view/consultant-e...
# 357  https://fr.linkedin.com/jobs/view/senior-clini...
# 360  https://fr.linkedin.com/jobs/view/developpeur-...
# 361  https://fr.linkedin.com/jobs/view/developpeur-...
# 363  https://fr.linkedin.com/jobs/view/internationa...
# 371  https://fr.linkedin.com/jobs/view/d%C3%A9velop...
#
#                                        location       date         skills  \
# 4              Montrouge, Île-de-France, France 2023-02-11  certification
# 11                 Paris, Île-de-France, France 2023-02-10  certification
# 63                 Paris, Île-de-France, France 2023-02-11  certification
# 82       Rueil-Malmaison, Île-de-France, France 2023-02-11  certification
# 99                 Paris, Île-de-France, France 2023-02-11  certification
# 113                Paris, Île-de-France, France 2023-02-11  certification
# 115                Paris, Île-de-France, France 2023-02-10  certification
# 132      Rueil-Malmaison, Île-de-France, France 2023-02-11  certification
# 156                Paris, Île-de-France, France 2023-02-11  certification
# 170                Paris, Île-de-France, France 2023-02-11  certification
# 174                Paris, Île-de-France, France 2023-02-10  certification
# 210           La Défense, Île-de-France, France 2023-02-11  certification
# 244                Paris, Île-de-France, France 2023-02-10  certification
# 254                Paris, Île-de-France, France 2023-02-11  certification
# 272                Paris, Île-de-France, France 2023-02-10  certification
# 274      Rueil-Malmaison, Île-de-France, France 2023-02-11  certification
# 281                Paris, Île-de-France, France 2023-02-11  certification
# 292                Paris, Île-de-France, France 2023-02-11  certification
# 307                Paris, Île-de-France, France 2023-02-11  certification
# 312                Paris, Île-de-France, France 2023-02-11  certification
# 315                Paris, Île-de-France, France 2023-02-11  certification
# 316                Paris, Île-de-France, France 2023-02-11  certification
# 323                Paris, Île-de-France, France 2023-02-11  certification
# 325                Paris, Île-de-France, France 2023-02-11  certification
# 329                Paris, Île-de-France, France 2023-02-11  certification
# 347                Paris, Île-de-France, France 2023-02-11  certification
# 351                Paris, Île-de-France, France 2023-02-11  certification
# 357      Rueil-Malmaison, Île-de-France, France 2023-02-11  certification
# 360               Bezons, Île-de-France, France 2023-02-10  certification
# 361               Bezons, Île-de-France, France 2023-02-10  certification
# 363  Issy-les-Moulineaux, Île-de-France, France 2023-02-11  certification
# 371                Paris, Île-de-France, France 2023-02-11  certification
#
#           new_title
# 4       Data Autres
# 11   Data Scientist
# 63           Autres
# 82           Autres
# 99      Data Autres
# 113     Data Autres
# 115     Data Autres
# 132          Autres
# 156     Data Autres
# 170     Data Autres
# 174     Data Autres
# 210          Autres
# 244          Autres
# 254     Data Autres
# 272          Autres
# 274          Autres
# 281          Autres
# 292          Autres
# 307     Data Autres
# 312          Autres
# 315          Autres
# 316          Autres
# 323          Autres
# 325          Autres
# 329          Autres
# 347     Data Autres
# 351     Data Autres
# 357     Data Autres
# 360          Autres
# 361          Autres
# 363   Consultant BI
# 371          Autres

# %%
def get_url_from_id(job_id):
  try:
    return df[df['id'] == job_id].iloc[0,:]['url']
  except:
    pass

get_url_from_id(3479715150)
# Out:
# 'https://fr.linkedin.com/jobs/view/d%C3%A9veloppeur-python-h-f-at-ilyeum-3479715150?refId=kNsMv10IBqqb0wHfJMAEqg%3D%3D&trackingId=LTi4Kz1dVw0MpIkHkK3gCw%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card'

# %%
df['id'].value_counts()
# Out:
# 3478057380    3
# 3478705871    3
# 3450777859    3
# 3467033977    2
# 3303569805    2
#              ..
# 3477130693    1
# 3479577886    1
# 3479584161    1
# 3479576738    1
# 3266840148    1
# Name: id, Length: 314, dtype: int64
